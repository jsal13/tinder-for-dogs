# %%
import pandas as pd
import numpy as np
import os, re

# %%
path_to_folder = os.path.expanduser("~/Downloads/images/")

# %%
[{i: {'metadata': {
    'dog-social': 0,
    'human-social': 0,
    'hypoallergenic': 0,
    'child-friendly': 0,
    'size': 0,
    'trainable': 0
}}} for i in os.listdir(path_to_folder)]
# Out:
# [{'n02085620-Chihuahua': {'metadata': {'dog-social': 0,
#     'human-social': 0,
#     'hypoallergenic': 0,
#     'child-friendly': 0,
#     'size': 0,
#     'trainable': 0}}},
#  {'n02085782-Japanese_spaniel': {'metadata': {'dog-social': 0,
#     'human-social': 0,
#     'hypoallergenic': 0,
#     'child-friendly': 0,
#     'size': 0,
#     'trainable': 0}}},
#  {'n02085936-Maltese_dog': {'metadata': {'dog-social': 0,
#     'human-social': 0,
#     'hypoallergenic': 0,
#     'child-friendly': 0,
#     'size': 0,
#     'trainable': 0}}},
#  {'n02086079-Pekinese': {'metadata': {'dog-social': 0,
#     'human-social': 0,
#     'hypoallergenic': 0,
#     'child-friendly': 0,
#     'size': 0,
#     'trainable': 0}}},
#  {'n02086240-Shih-Tzu': {'metadata': {'dog-social': 0,
#     'human-social': 0,
#     'hypoallergenic': 0,
#     'child-friendly': 0,
#     'size': 0,
#     'trainable': 0}}},
#  {'n02086646-Blenheim_spaniel': {'metadata': {'dog-social': 0,
#     'human-social': 0,
# ...
